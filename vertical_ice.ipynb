# %%
import numpy as np
import xarray as xr
from matplotlib import pyplot as plt
import gsw

import cmocean.cm as cmo
from xgcm import Grid

# %%
ds = xr.open_dataset("vertical_ice_face_3Dsolution_v1.nc", decode_timedelta=True)
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 11, y_afa: 128, x_faa: 129, x_caa: 128, y_aca: 128,
#               z_aaf: 129, z_aac: 128)
# Coordinates:
#   * time     (time) timedelta64[ns] 00:00:00 00:01:00 ... 00:09:00 00:10:00
#   * y_afa    (y_afa) float64 0.0 0.03906 0.07812 0.1172 ... 4.883 4.922 4.961
#   * x_faa    (x_faa) float64 -0.0 0.04344 0.08688 0.1303 ... 9.345 9.663 10.0
#   * x_caa    (x_caa) float64 0.02172 0.06516 0.1086 0.1521 ... 9.194 9.504 9.831
#   * y_aca    (y_aca) float64 0.01953 0.05859 0.09766 0.1367 ... 4.902 4.941 4.98
#   * z_aaf    (z_aaf) float64 0.0 0.07812 0.1562 0.2344 ... 9.844 9.922 10.0
#   * z_aac    (z_aac) float64 0.03906 0.1172 0.1953 0.2734 ... 9.805 9.883 9.961
# Data variables:
#     Δx_caa   (x_caa) float32 ...
#     Δx_faa   (x_faa) float32 ...
#     Δy_aca   (y_aca) float32 ...
#     Δy_afa   (y_afa) float32 ...
#     Δz_aac   (z_aac) float32 ...
#     Δz_aaf   (z_aaf) float32 ...
#     S        (time, z_aac, y_aca, x_caa) float32 ...
# ...

# %%
ds.T.isel(time=-1, y_aca=0).plot(robust=True, cmap=cmo.thermal)

# %%
ds.S.isel(time=-1, y_aca=0).plot(robust=True, cmap=cmo.haline)

# %%
ds.T.isel(time=-1, x_caa=3).plot(robust=True, cmap=cmo.thermal)

# %%
ds.S.isel(time=-1, x_caa=3).plot(robust=True, cmap=cmo.haline)
